# %%
pip install slack_bolt
# Out:
# Requirement already satisfied: slack_bolt in /usr/local/lib/python3.7/site-packages (1.3.0)
# Requirement already satisfied: slack-sdk<3.4,>=3.3.0 in /usr/local/lib/python3.7/site-packages (from slack_bolt) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
import re
import jsbeautifier
from slack_bolt import App
from slack_sdk import WebClient
from slack_sdk.errors import SlackApiError
import pandas as pd
import io

client = WebClient(token="xoxp-1664119445540-1643181234759-1696879914535-84e258c25d9ec7c1ecfd11f03f42cfa0")

app = App(
    token=("xoxb-1664119445540-1701240028835-15Bzsi8TbnZ7773DkBw6qi1P"),
    signing_secret=("94c1b74f6044d8382ca77173059da4eb")
)

def get_channel_message_history():
    conversation_history = []
    channel_id = "C01KC4QD951"
    try:    
        result = (client.conversations_history(channel=channel_id))
        print(type(result))
        return(result)
        # print(result)
        # print(type(result))
    except SlackApiError as e:
        print(e)


def interp_data():
    data = io.StringIO(get_channel_message_history())
    header = ["type", "user", "text", "ts"]
    df=pd.read_csv(data, names=header)
    print(df)
    print(type(df))
    
data = get_channel_message_history()
data=data["messages"]
data = pd.DataFrame(data)
data
    # data = json.dumps(get_channel_message_history())
    # # df = pd.read_csv(data)
    # print(type(data))
    # print(data)
# Out:
# <class 'slack_sdk.web.slack_response.SlackResponse'>
#                            client_msg_id     type  \
# 0   51CA3213-42FB-4BFB-B03B-7E789F0381E5  message
# 1   11AB61E8-D774-42E9-B664-D02FA242B449  message
# 2   1c8b642e-e8c6-41c8-b58c-282e41601f9e  message
# 3   022EEA26-79B8-431A-9AAA-40C83175C053  message
# 4   23883C93-6CD6-4FB3-816A-1336E92E527C  message
# ..                                   ...      ...
# 95  08CCFD69-DBEA-40CE-8868-3316FA2374A7  message
# 96  ba222b6b-e9fc-4a7f-b335-0876bf042f59  message
# 97  909C532A-C082-4898-B6CA-37E6EDB63BC5  message
# 98  418B562B-3735-4A00-91DF-27C656143BC2  message
# 99  942b03f2-da35-4375-92d5-7fddab3b4a17  message
#
#                                                  text         user  \
# 0                  Oh yay, I totally forgot I’m sorry  U01KC4VGPGB
# 1   It went pretty well ! He said he’d python pack...  U01K8RNVC4V
# 2                               How'd the meeting go?  U01JX5G6SH5
# 3   Hey everyone, Chris and I are meeting at 11 a....  U01K8RNVC4V
# 4   I have a new name idea! Team Mom! Our product ...  U01KC4VGPGB
# ..                                                ...          ...
# 95                                          Yeah 4 CT  U01K8RNVC4V
# 96                                              at 4?  U01JX5G6SH5
# 97                                              Yes!   U01K8RNVC4V
# 98                       I think we definitely should  U01KC4VGPGB
# 99                              Are we meeting today?  U01JX5G6SH5
#
#                    ts         team  \
# 0   1613087797.001900  T01KJ3HD3FW
# 1   1613087359.001500  T01KJ3HD3FW
# 2   1613075750.000200  T01KJ3HD3FW
# 3   1612986490.001800  T01KJ3HD3FW
# 4   1612926304.002400  T01KJ3HD3FW
# ..                ...          ...
# 95  1611519457.001300  T01KJ3HD3FW
# 96  1611519438.000900  T01KJ3HD3FW
# 97  1611519430.000700  T01KJ3HD3FW
# 98  1611519426.000500  T01KJ3HD3FW
# 99  1611519387.000200  T01KJ3HD3FW
#
#                                                blocks  \
# 0   [{'type': 'rich_text', 'block_id': 'js2/', 'el...
# 1   [{'type': 'rich_text', 'block_id': 'Gw1', 'ele...
# 2   [{'type': 'rich_text', 'block_id': 'fly', 'ele...
# 3   [{'type': 'rich_text', 'block_id': 'kuumy', 'e...
# 4   [{'type': 'rich_text', 'block_id': 'WUI', 'ele...
# ..                                                ...
# 95  [{'type': 'rich_text', 'block_id': 'n0ROH', 'e...
# 96  [{'type': 'rich_text', 'block_id': 'eZ39V', 'e...
# 97  [{'type': 'rich_text', 'block_id': 'oXOb', 'el...
# 98  [{'type': 'rich_text', 'block_id': 'j4js1', 'e...
# 99  [{'type': 'rich_text', 'block_id': 'tKuw', 'el...
#
#                                             reactions files upload  \
# 0                                                 NaN   NaN    NaN
# 1   [{'name': 'raised_hands', 'users': ['U01JX5G6S...   NaN    NaN
# 2                                                 NaN   NaN    NaN
# 3   [{'name': '+1', 'users': ['U01JX5B6WNB'], 'cou...   NaN    NaN
# 4                                                 NaN   NaN    NaN
# ..                                                ...   ...    ...
# 95  [{'name': '+1', 'users': ['U01JX5G6SH5'], 'cou...   NaN    NaN
# 96  [{'name': '+1', 'users': ['U01KC4VGPGB'], 'cou...   NaN    NaN
# 97                                                NaN   NaN    NaN
# 98                                                NaN   NaN    NaN
# 99                                                NaN   NaN    NaN
#
#    display_as_bot attachments subtype bot_id bot_link inviter edited
# 0             NaN         NaN     NaN    NaN      NaN     NaN    NaN
# 1             NaN         NaN     NaN    NaN      NaN     NaN    NaN
# 2             NaN         NaN     NaN    NaN      NaN     NaN    NaN
# 3             NaN         NaN     NaN    NaN      NaN     NaN    NaN
# 4             NaN         NaN     NaN    NaN      NaN     NaN    NaN
# ..            ...         ...     ...    ...      ...     ...    ...
# 95            NaN         NaN     NaN    NaN      NaN     NaN    NaN
# 96            NaN         NaN     NaN    NaN      NaN     NaN    NaN
# 97            NaN         NaN     NaN    NaN      NaN     NaN    NaN
# 98            NaN         NaN     NaN    NaN      NaN     NaN    NaN
# 99            NaN         NaN     NaN    NaN      NaN     NaN    NaN
#
# [100 rows x 17 columns]

# %%
df = data[['client_msg_id', 'type', 'text', 'user', 'ts', 'reactions']]
df
# Out:
#                            client_msg_id     type  \
# 0   51CA3213-42FB-4BFB-B03B-7E789F0381E5  message
# 1   11AB61E8-D774-42E9-B664-D02FA242B449  message
# 2   1c8b642e-e8c6-41c8-b58c-282e41601f9e  message
# 3   022EEA26-79B8-431A-9AAA-40C83175C053  message
# 4   23883C93-6CD6-4FB3-816A-1336E92E527C  message
# ..                                   ...      ...
# 95  08CCFD69-DBEA-40CE-8868-3316FA2374A7  message
# 96  ba222b6b-e9fc-4a7f-b335-0876bf042f59  message
# 97  909C532A-C082-4898-B6CA-37E6EDB63BC5  message
# 98  418B562B-3735-4A00-91DF-27C656143BC2  message
# 99  942b03f2-da35-4375-92d5-7fddab3b4a17  message
#
#                                                  text         user  \
# 0                  Oh yay, I totally forgot I’m sorry  U01KC4VGPGB
# 1   It went pretty well ! He said he’d python pack...  U01K8RNVC4V
# 2                               How'd the meeting go?  U01JX5G6SH5
# 3   Hey everyone, Chris and I are meeting at 11 a....  U01K8RNVC4V
# 4   I have a new name idea! Team Mom! Our product ...  U01KC4VGPGB
# ..                                                ...          ...
# 95                                          Yeah 4 CT  U01K8RNVC4V
# 96                                              at 4?  U01JX5G6SH5
# 97                                              Yes!   U01K8RNVC4V
# 98                       I think we definitely should  U01KC4VGPGB
# 99                              Are we meeting today?  U01JX5G6SH5
#
#                    ts                                          reactions
# 0   1613087797.001900                                                NaN
# 1   1613087359.001500  [{'name': 'raised_hands', 'users': ['U01JX5G6S...
# 2   1613075750.000200                                                NaN
# 3   1612986490.001800  [{'name': '+1', 'users': ['U01JX5B6WNB'], 'cou...
# 4   1612926304.002400                                                NaN
# ..                ...                                                ...
# 95  1611519457.001300  [{'name': '+1', 'users': ['U01JX5G6SH5'], 'cou...
# 96  1611519438.000900  [{'name': '+1', 'users': ['U01KC4VGPGB'], 'cou...
# 97  1611519430.000700                                                NaN
# 98  1611519426.000500                                                NaN
# 99  1611519387.000200                                                NaN
#
# [100 rows x 6 columns]

# %%
df['user'].value_counts()
# Out:
# U01KC4VGPGB    30
# U01JX5G6SH5    24
# U01K8RNVC4V    22
# U01JX5B6WNB    19
# USLACKBOT       2
# U01KUETLX35     1
# U01LM720UQK     1
# Name: user, dtype: int64

# %%
frequencies = df['user'].value_counts()

# %%
frequencies
# Out:
# U01KC4VGPGB    30
# U01JX5G6SH5    24
# U01K8RNVC4V    22
# U01JX5B6WNB    19
# USLACKBOT       2
# U01KUETLX35     1
# U01LM720UQK     1
# Name: user, dtype: int64

# %%
messages = df['text']
Progress_Messages = pd.DataFrame(columns=['Flagged'])
Progress_Messages
# Out:
# Empty DataFrame
# Columns: [Flagged]
# Index: []

# %%
finished = messages.str.contains(r'finish*', regex=True)
for x in range(len(finished)-1):
    if finished[x]==True:
        adding = {'Flagged': messages[x]}
        Progress_Messages=Progress_Messages.append(adding, ignore_index=True)
        finished = messages.str.contains(r'finish*', regex=True)
        
completed = messages.str.contains(r'complet*', regex=True)
for x in range(len(completed)-1):
    if completed[x]==True:
        adding = {'Flagged': messages[x]}
        Progress_Messages=Progress_Messages.append(adding, ignore_index=True)
        completed = messages.str.contains(r'complet*', regex=True)
        
idea = messages.str.contains(r'idea*', regex=True)
for x in range(len(idea)-1):
    if idea[x]==True:
        adding = {'Flagged': messages[x]}
        Progress_Messages=Progress_Messages.append(adding, ignore_index=True)
        idea = messages.str.contains(r'idea*', regex=True)
        
done = messages.str.contains(r'done*', regex=True)
for x in range(len(done)-1):
    if done[x]==True:
        adding = {'Flagged': messages[x]}
        Progress_Messages=Progress_Messages.append(adding, ignore_index=True)
        done = messages.str.contains(r'done*', regex=True)
        
accomplish = messages.str.contains(r'accomplish*', regex=True)
for x in range(len(accomplish)-1):
    if accomplish[x]==True:
        adding = {'Flagged': messages[x]}
        Progress_Messages=Progress_Messages.append(adding, ignore_index=True)
        accomplish = messages.str.contains(r'accomplish*', regex=True)
        
accquire = messages.str.contains(r'accquir*', regex=True)
for x in range(len(accquire)-1):
    if accquire[x]==True:
        adding = {'Flagged': messages[x]}
        Progress_Messages=Progress_Messages.append(adding, ignore_index=True)
        accquire = messages.str.contains(r'accquire*', regex=True)
        
agree = messages.str.contains(r'agree*', regex=True)
for x in range(len(agree)-1):
    if agree[x]==True:
        adding = {'Flagged': messages[x]}
        Progress_Messages=Progress_Messages.append(adding, ignore_index=True)
        agree = messages.str.contains(r'agree*', regex=True)

# %%
Progress_Messages
# Out:
#                                              Flagged
# 0  I have a new name idea! Team Mom! Our product ...
# 1  Guys! Alphabet has a free API for identifying ...
# 2  I don’t think it works unless Isaac starts the...
# 3  It seems like we don't have class this week/ju...
# 4  <@U01K8RNVC4V> when you were gone, we agreed o...
